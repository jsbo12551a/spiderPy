# %% [markdown]
# # YAHOO電影爬蟲練習
# ## 練習爬取電影放映資訊。必須逐步獲取電影的代號、放映地區、放映日期後，再送出查詢給伺服器。

# %%
import requests
import re
from bs4 import BeautifulSoup

# %% [markdown]
# ### 先搜尋全部的電影代號(ID)資訊

# %%
# 查看目前上映那些電影，並擷取出其ID資訊
url = 'https://movies.yahoo.com.tw/'
resp = requests.get(url)
resp.encoding = 'utf-8'

soup = BeautifulSoup(resp.text, 'lxml')
html = soup.find("select", attrs={'name':'movie_id'})
movie_item = html.find_all("option", attrs={'data-name':re.compile('.*')})
# movie_item
for p in movie_item:
    print("Movie: %s, ID: %s" % (p["data-name"], p["value"]))
# Out:
# Movie: 金魚, ID: 10424
# Movie: 海上花, ID: 10376
# Movie: 奪魂露營車, ID: 10366
# Movie: 世紀球王 馬拉度納, ID: 10361
# Movie: 怨靈古堡, ID: 10356
# Movie: 添好孕, ID: 10332
# Movie: 外出偷馬, ID: 10310
# Movie: 茱蒂, ID: 10112
# Movie: 燃燒女子的畫像, ID: 10069
# Movie: 葉問4：完結篇, ID: 9890
# Movie: STAR WARS : 天行者的崛起, ID: 10225
# Movie: 復仇母親, ID: 10392
# Movie: 風暴過後, ID: 10387
# Movie: 南方車站的聚會, ID: 10380
# Movie: 祭旗, ID: 10373
# Movie: 唯你是愛, ID: 10370
# Movie: 屍控療法, ID: 10367
# Movie: 黑熊來了, ID: 10357
# Movie: 唐人街探案2, ID: 10353
# Movie: 黑計畫, ID: 10351
# Movie: HUMAN LOST人間失格, ID: 10348
# Movie: 假面騎士劇場版ZI-O Over Quartzer, ID: 10331
# Movie: 巴黎小情聖, ID: 10329
# Movie: 每個月來訪一次的月經醬, ID: 10324
# Movie: 8級警戒, ID: 10323
# Movie: 為你存在的每一天, ID: 10297
# Movie: 黑色聖誕節, ID: 10291
# Movie: 熱氣球飛行家, ID: 10257
# Movie: 大說謊家, ID: 10122
# Movie: 特約經紀公司, ID: 10364
# Movie: 花生醬獵鷹的願望, ID: 10340
# Movie: 我的靈魂是愛做的, ID: 10336
# Movie: 絕世情歌, ID: 10328
# Movie: 人間失格：太宰治與他的3個女人, ID: 10287
# Movie: 呆萌特務, ID: 10264
# Movie: 去年聖誕節, ID: 10256
# Movie: 野蠻遊戲：全面晉級, ID: 10134
# Movie: 夕霧花園, ID: 10327
# Movie: 懸案密碼前傳：瓶中信, ID: 10254
# Movie: 布魯克林孤兒, ID: 10224
# Movie: 暴走曼哈頓, ID: 10044
# Movie: 鋒迴路轉, ID: 10258
# Movie: 賽道狂人, ID: 10097
# Movie: 82年生的金智英, ID: 10298
# Movie: 冰雪奇緣2, ID: 9597
# Movie: Hello World, ID: 10302
# Movie: 萬萬沒想到, ID: 10281
# Movie: 為美好的世界獻上祝福！紅傳說, ID: 10226
# Movie: 山田孝之的痛苦與榮耀, ID: 10301
# Movie: 決戰中途島, ID: 10130
# Movie: 地久天長, ID: 9621
# Movie: 魔鬼終結者：黑暗宿命, ID: 10067
# Movie: 陽光普照, ID: 10240
# Movie: 狙擊獵殺：救援行動, ID: 10284
# Movie: 金翅雀, ID: 10072
# Movie: 盲人律師, ID: 10267
# Movie: 海獸之子, ID: 10263
# Movie: 電影版 壞傢伙們, ID: 10249
# Movie: 江湖無難事, ID: 10241
# Movie: 藍波：最後一滴血, ID: 10205
# Movie: 屍樂園：髒比雙拼, ID: 10176
# Movie: 弒婚遊戲, ID: 10171
# Movie: 108悍將, ID: 10238
# Movie: 校外打怪教學, ID: 10200
# Movie: 信用詐欺師JP, ID: 10190
# Movie: 星際救援, ID: 10227
# Movie: 唐頓莊園, ID: 10064
# Movie: 衝擊真相, ID: 10215
# Movie: 舞孃騙很大, ID: 10199
# Movie: 夜鶯的哭聲, ID: 10191
# Movie: 好小男孩, ID: 9894
# Movie: 大叔之愛電影版, ID: 10136
# Movie: 牠 第二章, ID: 10042
# Movie: 下半場, ID: 9807
# Movie: 全面攻佔3：天使救援, ID: 10082
# Movie: 普羅米亞, ID: 10119
# Movie: 朵拉與失落的黃金城, ID: 9920
# Movie: 獅子王, ID: 9116
# Movie: 玩具總動員4, ID: 9924
# Movie: 毀滅者, ID: 9405
# Movie: 庫爾斯克號：深海救援, ID: 9134
# Movie: 厄夜追緝令, ID: 9589
# Movie: 苦兒流浪記, ID: 9538
# Movie: 活個精彩, ID: 9394
# Movie: 限時好友, ID: 9578
# Movie: 祝你忌日快樂, ID: 9568
# Movie: 艾莉塔：戰鬥天使, ID: 8553
# Movie: 馴龍高手3, ID: 8350
# Movie: 幸福綠皮書, ID: 9150
# Movie: 巴黎電幻世代, ID: 5967
# Movie: 一首搖滾上月球, ID: 4887
# Movie: 錢不夠用2, ID: 3026

# %% [markdown]
# ### 指定你有興趣的電影其ID，然後查詢其放映地區資訊。

# %%
# 參考前一個步驟中擷取到的ID資訊，並指定ID
movie_id = 10257

# %%
url = 'https://movies.yahoo.com.tw/api/v1/areas_by_movie_theater'
payload = {'movie_id':str(movie_id)}

# 模擬一個header
headers = {
    'authority': 'movies.yahoo.com.tw',
    'method': 'GET',
    'path': '/api/v1/areas_by_movie_theater?movie_id=' + str(movie_id),
    'scheme': 'https',
    'accept': 'application/json, text/javascript, */*; q=0.01',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6',
    'cookie': 'rxx=9s3x2fws06.1g16irnc&v=1; _ga=GA1.3.2056742944.1551651301; GUC=AQEBAQFczFpdm0IfmwSB&s=AQAAACoo4N5D&g=XMsVBw; BX=4hkdk1decm57t&b=3&s=mr; _ga=GA1.4.2056742944.1551651301; nexagesuid=82843256dd234e8e91aa73f2062f8218; browsed_movie=; avi=eyJpdiI6Im1NeWFJRlVRWDR1endEcGRGUGJUbVE9PSIsInZhbHVlIjoickRpU3JuUytmcGl6cjF5OW0rNU9iZz09IiwibWFjIjoiY2VmY2NkNzZmM2NhNjY5YzlkOTcyNjE5OGEyMzU0NWYxOTdmMDRkMDY3OWNmMmZjOTMxYjc5MjI5N2Q5NGE5MiJ9; cmp=t=1559391030&j=0; _gid=GA1.4.779543841.1559391031; XSRF-TOKEN=%3D; m_s=; _gat=1; nexagesd=10',
    'dnt': '1',
    'mv-authorization': '21835b082e15b91a69b3851eec7b31b82ce82afb',
    'referer': 'https://movies.yahoo.com.tw/',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36',
    'x-requested-with': 'XMLHttpRequest',
}
    
resp = requests.get(url, params=payload, headers=headers)
# print(resp.json())  # 若有需要，列印出json原始碼

# 這裡回傳的格式是JSON格式的資料，要解析JSON擷取資料
for p in resp.json():
    print('放映地區: {0}, 代號(area_id): {1}'.format(p['title'], p['area_id']))
# Out:
# [{'area_id': 28, 'title': '台北市', 'priority': 150, 'ts_update': 1547519309}, {'area_id': 8, 'title': '新北市', 'priority': 145, 'ts_update': 1547194527}, {'area_id': 16, 'title': '桃園', 'priority': 140, 'ts_update': 1547452573}, {'area_id': 2, 'title': '台中', 'priority': 125, 'ts_update': 1547507368}, {'area_id': 10, 'title': '台南', 'priority': 100, 'ts_update': 1547507403}, {'area_id': 17, 'title': '高雄', 'priority': 95, 'ts_update': 1547507403}, {'area_id': 14, 'title': '屏東', 'priority': 90, 'ts_update': 1547507403}]
# 放映地區: 台北市, 代號(area_id): 28
# 放映地區: 新北市, 代號(area_id): 8
# 放映地區: 桃園, 代號(area_id): 16
# 放映地區: 台中, 代號(area_id): 2
# 放映地區: 台南, 代號(area_id): 10
# 放映地區: 高雄, 代號(area_id): 17
# 放映地區: 屏東, 代號(area_id): 14

# %% [markdown]
# ### 指定你想要觀看的放映地區，查詢有上映電影的場次日期

# %%
# 指定放映地區
area_id = 28

# %%
# 向網站發送請求
url = 'https://movies.yahoo.com.tw/movietime_result.html'
payload = {'movie_id':str(movie_id), 'area_id':str(area_id)}
resp = requests.get(url, params=payload)
resp.encoding = 'utf-8'

soup = BeautifulSoup(resp.text, 'lxml')
movie_date = soup.find_all("label", attrs={'for':re.compile("date_[\d]")})

# 列印播放日期
for date in movie_date:
    print("%s %s" % (date.p.string, date.h3.string))
# Out:
# 十二月 20
# 十二月 21
# 十二月 22
# 十二月 23
# 十二月 24

# %% [markdown]
# ### 最後指定觀看的日期，查詢並列印出放映的電影院、放映類型(數位、3D、IMAX 3D...)、放映時間等資訊。

# %%
# 選定要觀看的日期
date = "2019-12-20"

# %%
# 向網站發送請求，獲取上映的電影院及時間資訊
url = "https://movies.yahoo.com.tw/ajax/pc/get_schedule_by_movie"
payload = {'movie_id':str(movie_id),
           'date':date,
           'area_id':str(area_id),
           'theater_id':'',
           'datetime':'',
           'movie_type_id':''}

resp = requests.get(url, params=payload)
# print(resp.json()['view'])  # 若有需要，列印出json原始碼
# print(resp.text)
soup = BeautifulSoup(resp.json()['view'], 'lxml')
html = soup.find_all("ul", attrs={'data-theater_name':re.compile(".*")})
# html
# Out:
# [<ul class="area_time _c jq_area_time" data-theater_name="國賓影城(台北長春廣場)" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=29" data-theater_url="http://www.ambassador.com.tw/" id="theater_id_29">
#  <li class="adds">
#  <a href="https://movies.yahoo.com.tw/theater_result.html/id=29">國賓影城(台北長春廣場)</a>
#  <span>02-25155755</span>
#  </li>
#  <li class="taps">
#  <span class="tapR">數位</span> </li>
#  <li class="time _c">
#  <div class="input_picker jq_input_picker">
#  <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '熱氣球飛行家']" data-movie_date="12.20" data-movie_time="11:30" data-movie_title="熱氣球飛行家" data-movie_type="數位" data-news="news" id="72616962" name="schedule_list" type="radio" value="2019-12-20 11:30:00"/>
#  <label class="" for="72616962">11:30</label>
#  </div>
#  </li>
#  </ul>,
#  <ul class="area_time _c jq_area_time" data-theater_name="欣欣秀泰影城" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=30" data-theater_url="http://www.showtimes.com.tw/" id="theater_id_30">
#  <li class="adds">
#  <a href="https://movies.yahoo.com.tw/theater_result.html/id=30">欣欣秀泰影城</a>
#  <span>02-25371889</span>
#  </li>
#  <li class="taps">
#  <span class="tapR">數位</span> </li>
#  <li class="time _c">
#  <div class="input_picker jq_input_picker">
#  <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '熱氣球飛行家']" data-movie_date="12.20" data-movie_time="17:05" data-movie_title="熱氣球飛行家" data-movie_type="數位" data-news="news" id="72617039" name="schedule_list" type="radio" value="2019-12-20 17:05:00"/>
#  <label class="select" for="72617039">17:05</label>
#  </div>
#  </li>
#  </ul>,
#  <ul class="area_time _c jq_area_time" data-theater_name="台北美麗華大直影城" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=32" data-theater_url="http://www.miramarcinemas.tw/" id="theater_id_32">
#  <li class="adds">
#  <a href="https://movies.yahoo.com.tw/theater_result.html/id=32">台北美麗華大直影城</a>
#  <span>02-85022208</span>
#  </li>
#  <li class="taps">
#  <span class="tapR">數位</span> </li>
#  <li class="time _c">
#  <div class="input_picker jq_input_picker">
#  <input class="gabtn" data-cinema="40288eb0050f31210ada0f55676b1bbc" data-date="1576771200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '熱氣球飛行家']" data-movie="cf6d74c757f64215b23f93c5c27d564f" data-movie_date="12.20" data-movie_time="18:00" data-movie_title="熱氣球飛行家" data-movie_type="數位" data-session="27067dffacd44cdd962d82c45835b61d" data-time="1576836000" id="72596894" name="schedule_list" type="radio" value="2019-12-20 18:00:00"/>
#  <label class="select" for="72596894">18:00</label>
#  </div>
#  </li>
#  </ul>,
#  <ul class="area_time _c jq_area_time" data-theater_name="華威天母影城" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=33" data-theater_url="http://www.woviecinemas.com.tw/" id="theater_id_33">
#  <li class="adds">
#  <a href="https://movies.yahoo.com.tw/theater_result.html/id=33">華威天母影城</a>
#  <span>02-28763300</span>
#  </li>
#  <li class="taps">
#  <span class="tapR">數位</span> </li>
#  <li class="time _c">
#  <div class="input_picker jq_input_picker">
#  <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '熱氣球飛行家']" data-movie_date="12.20" data-movie_time="17:40" data-movie_title="熱氣球飛行家" data-movie_type="數位" data-news="news" id="72617111" name="schedule_list" type="radio" value="2019-12-20 17:40:00"/>
#  <label class="select" for="72617111">17:40</label>
#  </div>
#  </li>
#  </ul>,
#  <ul class="area_time _c jq_area_time" data-theater_name="台北樂聲影城" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=38" data-theater_url="http://www.luxcinema.com.tw/" id="theater_id_38">
#  <li class="adds">
#  <a href="https://movies.yahoo.com.tw/theater_result.html/id=38">台北樂聲影城</a>
#  <span>02-23118628</span>
#  </li>
#  <li class="taps">
#  <span class="tapR">數位</span> </li>
#  <li class="time _c">
#  <div class="input_picker jq_input_picker">
#  <input class="gabtn" data-cinema="46efa950eafa11e38b12987bdb90dba4" data-date="1576771200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '熱氣球飛行家']" data-movie="7737c613e69c4437b92bc9898c574c77" data-movie_date="12.20" data-movie_time="13:30" data-movie_title="熱氣球飛行家" data-movie_type="數位" data-session="60f16e7fdb5d436880a897d19fffed5b" data-time="1576819800" id="72611589" name="schedule_list" type="radio" value="2019-12-20 13:30:00"/>
#  <label class="select" for="72611589">13:30</label>
#  <input class="gabtn" data-cinema="46efa950eafa11e38b12987bdb90dba4" data-date="1576771200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '熱氣球飛行家']" data-movie="7737c613e69c4437b92bc9898c574c77" data-movie_date="12.20" data-movie_time="19:05" data-movie_title="熱氣球飛行家" data-movie_type="數位" data-session="8908f6c39bbc4c7c96bf9c65e0587ebf" data-time="1576839900" id="72611590" name="schedule_list" type="radio" value="2019-12-20 19:05:00"/>
#  <label class="select" for="72611590">19:05</label>
#  </div>
#  </li>
#  </ul>,
#  <ul class="area_time _c jq_area_time" data-theater_name="台北真善美劇院" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=41" data-theater_url="" id="theater_id_41">
#  <li class="adds">
#  <a href="https://movies.yahoo.com.tw/theater_result.html/id=41">台北真善美劇院</a>
#  <span>02-23312270</span>
#  </li>
#  <li class="taps">
#  <span class="tapR">數位</span> </li>
#  <li class="time _c">
#  <div class="input_picker jq_input_picker">
#  <input class="gabtn" data-cinema="f644412efbb811e58858f2128151146f" data-date="1576771200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '熱氣球飛行家']" data-movie="7fe34990c76c40b7b823541283ea6364" data-movie_date="12.20" data-movie_time="16:10" data-movie_title="熱氣球飛行家" data-movie_type="數位" data-session="0fe440babe454dfe892f655dc8203dd8" data-time="1576829400" id="72602422" name="schedule_list" type="radio" value="2019-12-20 16:10:00"/>
#  <label class="select" for="72602422">16:10</label>
#  </div>
#  </li>
#  </ul>,
#  <ul class="area_time _c jq_area_time" data-theater_name="喜滿客絕色影城" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=42" data-theater_url="http://www.cinema7.com.tw/" id="theater_id_42">
#  <li class="adds">
#  <a href="https://movies.yahoo.com.tw/theater_result.html/id=42">喜滿客絕色影城</a>
#  <span>02-23811339</span>
#  </li>
#  <li class="taps">
#  <span class="tapR">數位</span> </li>
#  <li class="time _c">
#  <div class="input_picker jq_input_picker">
#  <input class="gabtn" data-cinema="40288eb0050f542401050f55532606b5" data-date="1576771200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '熱氣球飛行家']" data-movie="07e745bc0b3b47dd8e5a071f8221ece4" data-movie_date="12.20" data-movie_time="23:10" data-movie_title="熱氣球飛行家" data-movie_type="數位" data-session="88afd3fc093f413188776e3fe480db7a" data-time="1576854600" id="72609413" name="schedule_list" type="radio" value="2019-12-20 23:10:00"/>
#  <label class="select" for="72609413">23:10</label>
#  </div>
#  </li>
#  </ul>,
#  <ul class="area_time _c jq_area_time" data-theater_name="台北信義威秀影城" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=45" data-theater_url="http://www.vscinemas.com.tw/" id="theater_id_45">
#  <li class="adds">
#  <a href="https://movies.yahoo.com.tw/theater_result.html/id=45">台北信義威秀影城</a>
#  <span>02-87805566</span>
#  </li>
#  <li class="taps">
#  <span class="tapR">數位</span> </li>
#  <li class="time _c">
#  <div class="input_picker jq_input_picker">
#  <input class="gabtn" data-cinema="40288eb0050f542401050f554e7e0674" data-date="1576771200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '熱氣球飛行家']" data-movie="7d80b3cf6c474d7d83580245573a9fd9" data-movie_date="12.20" data-movie_time="13:15" data-movie_title="熱氣球飛行家" data-movie_type="數位" data-session="3067dd26bb8a47c3bd4a2749e0914c15" data-time="1576818900" id="72610844" name="schedule_list" type="radio" value="2019-12-20 13:15:00"/>
#  <label class="select" for="72610844">13:15</label>
#  </div>
#  </li>
#  </ul>,
#  <ul class="area_time _c jq_area_time" data-theater_name="百老匯數位影城" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=52" data-theater_url="http://www.broadway-cineplex.com.tw/index.asp" id="theater_id_52">
#  <li class="adds">
#  <a href="https://movies.yahoo.com.tw/theater_result.html/id=52">百老匯數位影城</a>
#  <span>02-86636128</span>
#  </li>
#  <li class="taps">
#  <span class="tapR">數位</span> </li>
#  <li class="time _c">
#  <div class="input_picker jq_input_picker">
#  <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '熱氣球飛行家']" data-movie_date="12.20" data-movie_time="11:45" data-movie_title="熱氣球飛行家" data-movie_type="數位" data-news="news" id="72616851" name="schedule_list" type="radio" value="2019-12-20 11:45:00"/>
#  <label class="" for="72616851">11:45</label>
#  <input class="gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '熱氣球飛行家']" data-movie_date="12.20" data-movie_time="17:35" data-movie_title="熱氣球飛行家" data-movie_type="數位" data-news="news" id="72616852" name="schedule_list" type="radio" value="2019-12-20 17:35:00"/>
#  <label class="select" for="72616852">17:35</label>
#  </div>
#  </li>
#  </ul>,
#  <ul class="area_time _c jq_area_time" data-theater_name="梅花數位影院" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=126" data-theater_url="" id="theater_id_126">
#  <li class="adds">
#  <a href="https://movies.yahoo.com.tw/theater_result.html/id=126">梅花數位影院</a>
#  <span>02-27326968</span>
#  </li>
#  <li class="taps">
#  <span class="tapR">數位</span> </li>
#  <li class="time _c">
#  <div class="input_picker jq_input_picker">
#  <input class="gabtn" data-cinema="b020ba50fbc811e58858f2128151146f" data-date="1576771200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '熱氣球飛行家']" data-movie="420431bd21544cc2858cc27a720effdc" data-movie_date="12.20" data-movie_time="12:40" data-movie_title="熱氣球飛行家" data-movie_type="數位" data-session="8bce1e0b124945a2b189f0cc111831c4" data-time="1576816800" id="72595240" name="schedule_list" type="radio" value="2019-12-20 12:40:00"/>
#  <label class="" for="72595240">12:40</label>
#  </div>
#  </li>
#  </ul>,
#  <ul class="area_time _c jq_area_time" data-theater_name="喜樂時代影城南港店" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=186" data-theater_url="http://www.centuryasia.com.tw/default.aspx" id="theater_id_186">
#  <li class="adds">
#  <a href="https://movies.yahoo.com.tw/theater_result.html/id=186">喜樂時代影城南港店</a>
#  <span>02-27888185</span>
#  </li>
#  <li class="taps">
#  <span class="tapR">數位</span> </li>
#  <li class="time _c">
#  <div class="input_picker jq_input_picker">
#  <input class="gabtn" data-cinema="40288eb0050f542401050f5681782dc5" data-date="1576771200" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '熱氣球飛行家']" data-movie="c2ad612e9c7d4a89935d434828b7bd18" data-movie_date="12.20" data-movie_time="17:00" data-movie_title="熱氣球飛行家" data-movie_type="數位" data-session="cba9b325bcd7430da446f781729c8982" data-time="1576832400" id="72615778" name="schedule_list" type="radio" value="2019-12-20 17:00:00"/>
#  <label class="select" for="72615778">17:00</label>
#  </div>
#  </li>
#  </ul>]

# %%
for i in html:
    print(i.select('li a')[0].text)
    print(i.select('li .tapR')[0].text,end=' ')
    print(i.select('.gabtn')[0]['data-movie_title'],end=' ')
    print(i.select('.gabtn')[0]['value'])
    print('---')
# Out:
# 國賓影城(台北長春廣場)
# 數位 熱氣球飛行家 2019-12-20 11:30:00
# ---
# 欣欣秀泰影城
# 數位 熱氣球飛行家 2019-12-20 17:05:00
# ---
# 台北美麗華大直影城
# 數位 熱氣球飛行家 2019-12-20 18:00:00
# ---
# 華威天母影城
# 數位 熱氣球飛行家 2019-12-20 17:40:00
# ---
# 台北樂聲影城
# 數位 熱氣球飛行家 2019-12-20 13:30:00
# ---
# 台北真善美劇院
# 數位 熱氣球飛行家 2019-12-20 16:10:00
# ---
# 喜滿客絕色影城
# 數位 熱氣球飛行家 2019-12-20 23:10:00
# ---
# 台北信義威秀影城
# 數位 熱氣球飛行家 2019-12-20 13:15:00
# ---
# 百老匯數位影城
# 數位 熱氣球飛行家 2019-12-20 11:45:00
# ---
# 梅花數位影院
# 數位 熱氣球飛行家 2019-12-20 12:40:00
# ---
# 喜樂時代影城南港店
# 數位 熱氣球飛行家 2019-12-20 17:00:00
# ---
